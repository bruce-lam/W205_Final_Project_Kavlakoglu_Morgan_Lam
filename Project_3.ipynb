# %% [markdown]
# # Executive Summary

# %% [markdown]
# ## Part 1: Linux Commands - Setup
#
# ### The following commands are executed once:
#
# #### set up project directory and branches
# ls
#
# cd w205
#
# git clone https://github.com/mids-w205-martin-mims/project-3-edakavlakoglu.git
#
# cd project-3-edakavlakoglu
#
# git branch assignment
#
# git checkout assignment
#
# #### copy yml file in project directory
# cp ~/w205/course-content/12-Querying-Data-II/docker-compose.yml .
#
# #### check yml file
# cat docker-compose.yml
#
# #### copy game_api python file and edit to include 'buy_a_sword' and 'join_guild' events
# cp ~/w205/course-content/12-Querying-Data-II/game_api.py .
#
# ### The following commands are executed every time I start a cluster:
#
# #### check for old containers
# docker ps -a
#
# #### start up cluster
# docker-compose up -d
#
# docker-compose ps
#
# #### create topic events
# docker-compose exec kafka kafka-topics --create --topic events --partitions 1 --replication-factor 1 --if-not-exists --bootstrap-server localhost:29092
#
# #### run flask
# docker-compose exec mids env FLASK_APP=/w205/project-3-edakavlakoglu/game_api.py flask run --host 0.0.0.0
#
# #### execute a bash shell in spark container in new terminal window
# docker-compose exec spark bash
#
# #### create symbolic link in spark container
# ln -s /w205 w205
#
# #### exit container
# exit
#
# #### run a jupyter notebook with pyspark kernel
# docker-compose exec spark env PYSPARK_DRIVER_PYTHON=jupyter PYSPARK_DRIVER_PYTHON_OPTS='notebook --no-browser --port 8888 --ip 0.0.0.0 --allow-root' pyspark
#
# #### check jupyter notebook exists
# ls
#
# #### start up jupyter notebook in incognito window (IP = 34.127.126.57)
# http://34.127.126.57:8888/?token=daa6b577712346d0f1e9ceb759ee67508d35af6d2aa472a3
#
# #### Run the Apache Bench commands in a separate terminal window:
#
# docker-compose exec mids ab -n 10 -H "Host: user1.comcast.com" http://localhost:5000/
#
# docker-compose exec mids ab -n 10 -H "Host: user1.comcast.com" http://localhost:5000/purchase_a_sword
#
# docker-compose exec mids ab -n 10 -H "Host: user2.att.com" http://localhost:5000/
#
# docker-compose exec mids ab -n 10 -H "Host: user2.att.com" http://localhost:5000/purchase_a_sword
#
# docker-compose exec mids ab -n 10 -H "Host: user1.comcast.com" http://localhost:5000/buy_a_sword
#
# docker-compose exec mids ab -n 10 -H "Host: user1.comcast.com" http://localhost:5000/join_guild
#
# docker-compose exec mids ab -n 10 -H "Host: user2.att.com" http://localhost:5000/buy_a_sword
#
# docker-compose exec mids ab -n 10 -H "Host: user2.att.com" http://localhost:5000/join_guild

# %% [markdown]
# ## Part 2: Exploring JSON file via Spark SQL

# %%
import json
from pyspark.sql import Row
from pyspark.sql.functions import udf, from_json
from pyspark.sql.types import StructType, StructField, StringType

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.18.0.6:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %% [markdown]
# ## Batch Mode

# %%
# Read json data from kafka

@udf('boolean')
def is_purchase(event_as_json):
    event = json.loads(event_as_json)
    if event['event_type'] == 'purchase_sword':
        return True
    return False

# %%
# Create a spark dataframe containing the extracted json data
raw_events = spark \
    .read \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "kafka:29092") \
    .option("subscribe", "events") \
    .option("startingOffsets", "earliest") \
    .option("endingOffsets", "latest") \
    .load()

# %%
raw_events.show()
# Out:
# +----+--------------------+------+---------+------+--------------------+-------------+
# | key|               value| topic|partition|offset|           timestamp|timestampType|
# +----+--------------------+------+---------+------+--------------------+-------------+
# |null|[7B 22 48 6F 73 7...|events|        0|     0|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     1|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     2|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     3|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     4|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     5|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     6|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     7|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     8|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|     9|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    10|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    11|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    12|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    13|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    14|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    15|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    16|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    17|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    18|2021-11-19 03:04:...|            0|
# |null|[7B 22 48 6F 73 7...|events|        0|    19|2021-11-19 03:04:...|            0|
# +----+--------------------+------+---------+------+--------------------+-------------+
# only showing top 20 rows

# %%
purchase_events = raw_events \
    .select(raw_events.value.cast('string').alias('raw'),
    raw_events.timestamp.cast('string')) \
    .filter(is_purchase('raw'))

# %%
purchase_events.show()
# Out:
# +--------------------+--------------------+
# |                 raw|           timestamp|
# +--------------------+--------------------+
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user1.c...|2021-11-19 03:04:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# |{"Host": "user2.a...|2021-11-19 03:05:...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
# Filter out only the purchase sword extracted events
extracted_purchase_events = purchase_events \
    .rdd \
    .map(lambda r: Row(timestamp=r.timestamp, **json.loads(r.raw))) \
    .toDF()

# %%
extracted_purchase_events.printSchema()
# Out:
# root
#  |-- Accept: string (nullable = true)
#  |-- Host: string (nullable = true)
#  |-- User-Agent: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- sword_size: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %%
extracted_purchase_events.show()
# Out:
# +------+-----------------+---------------+--------------+----------+--------------------+
# |Accept|             Host|     User-Agent|    event_type|sword_size|           timestamp|
# +------+-----------------+---------------+--------------+----------+--------------------+
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# +------+-----------------+---------------+--------------+----------+--------------------+
# only showing top 20 rows

# %%
# Write the purchase sword extracted events to parquet files stored in hdfs
extracted_purchase_events \
    .write \
    .mode('overwrite') \
    .parquet('/tmp/purchases')

# %%
# Read the parquet files from hdfs into another spark dataframe
purchases = spark.read.parquet('/tmp/purchases')

# %%
purchases.show()
# Out:
# +------+-----------------+---------------+--------------+----------+--------------------+
# |Accept|             Host|     User-Agent|    event_type|sword_size|           timestamp|
# +------+-----------------+---------------+--------------+----------+--------------------+
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# |   */*|    user2.att.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:05:...|
# +------+-----------------+---------------+--------------+----------+--------------------+
# only showing top 20 rows

# %%
# Register as a temp table to allow in memory sql against the dataframe
purchases.registerTempTable('purchases')

# %%
purchases_by_example2 = spark.sql("select * from purchases where host='user1.comcast.com'")

# %%
purchases_by_example2.show()
# Out:
# +------+-----------------+---------------+--------------+----------+--------------------+
# |Accept|             Host|     User-Agent|    event_type|sword_size|           timestamp|
# +------+-----------------+---------------+--------------+----------+--------------------+
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:04:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# |   */*|user1.comcast.com|ApacheBench/2.3|purchase_sword|     small|2021-11-19 03:41:...|
# +------+-----------------+---------------+--------------+----------+--------------------+
# only showing top 20 rows

# %%
# Convert to pandas
newdf = purchases_by_example2.toPandas()

# %%
newdf.describe()
# Out:
#        Accept               Host       User-Agent      event_type sword_size  \
# count    1620               1620             1620            1620       1620
# unique      1                  1                1               1          1
# top       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# freq     1620               1620             1620            1620       1620
#
#                       timestamp
# count                      1620
# unique                     1620
# top     2021-11-19 03:58:43.066
# freq                          1

# %%
newdf
# Out:
#      Accept               Host       User-Agent      event_type sword_size  \
# 0       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 2       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 3       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 4       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 5       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 6       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 7       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 8       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 9       */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 10      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 11      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 12      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 13      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 14      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 15      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 16      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 17      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 18      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 19      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 20      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 21      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 22      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 23      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 24      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 25      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 26      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 27      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 28      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 29      */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# ...     ...                ...              ...             ...        ...
# 1590    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1591    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1592    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1593    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1594    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1595    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1596    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1597    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1598    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1599    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1600    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1601    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1602    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1603    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1604    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1605    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1606    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1607    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1608    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1609    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1610    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1611    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1612    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1613    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1614    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1615    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1616    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1617    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1618    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
# 1619    */*  user1.comcast.com  ApacheBench/2.3  purchase_sword      small
#
#                     timestamp
# 0      2021-11-19 03:04:54.19
# 1     2021-11-19 03:04:54.197
# 2     2021-11-19 03:04:54.206
# 3     2021-11-19 03:04:54.212
# 4     2021-11-19 03:04:54.219
# 5     2021-11-19 03:04:54.223
# 6     2021-11-19 03:04:54.235
# 7     2021-11-19 03:04:54.255
# 8     2021-11-19 03:04:54.267
# 9     2021-11-19 03:04:54.272
# 10    2021-11-19 03:41:52.806
# 11    2021-11-19 03:41:52.809
# 12    2021-11-19 03:41:52.814
# 13    2021-11-19 03:41:52.817
# 14     2021-11-19 03:41:52.82
# 15    2021-11-19 03:41:52.823
# 16    2021-11-19 03:41:52.827
# 17    2021-11-19 03:41:52.832
# 18    2021-11-19 03:41:52.841
# 19    2021-11-19 03:41:52.846
# 20    2021-11-19 03:42:03.348
# 21    2021-11-19 03:42:03.355
# 22    2021-11-19 03:42:03.362
# 23    2021-11-19 03:42:03.367
# 24    2021-11-19 03:42:03.378
# 25    2021-11-19 03:42:03.382
# 26    2021-11-19 03:42:03.392
# 27    2021-11-19 03:42:03.396
# 28    2021-11-19 03:42:03.402
# 29    2021-11-19 03:42:03.408
# ...                       ...
# 1590  2021-11-19 04:09:35.325
# 1591  2021-11-19 04:09:35.334
# 1592  2021-11-19 04:09:35.341
# 1593  2021-11-19 04:09:35.348
# 1594  2021-11-19 04:09:35.355
# 1595   2021-11-19 04:09:35.36
# 1596  2021-11-19 04:09:35.366
# 1597  2021-11-19 04:09:35.372
# 1598  2021-11-19 04:09:35.378
# 1599  2021-11-19 04:09:35.384
# 1600  2021-11-19 04:09:46.186
# 1601  2021-11-19 04:09:46.192
# 1602  2021-11-19 04:09:46.195
# 1603  2021-11-19 04:09:46.199
# 1604  2021-11-19 04:09:46.202
# 1605  2021-11-19 04:09:46.208
# 1606  2021-11-19 04:09:46.213
# 1607  2021-11-19 04:09:46.216
# 1608   2021-11-19 04:09:46.22
# 1609  2021-11-19 04:09:46.223
# 1610  2021-11-19 04:09:56.776
# 1611  2021-11-19 04:09:56.783
# 1612  2021-11-19 04:09:56.788
# 1613  2021-11-19 04:09:56.793
# 1614  2021-11-19 04:09:56.797
# 1615  2021-11-19 04:09:56.801
# 1616  2021-11-19 04:09:56.805
# 1617  2021-11-19 04:09:56.809
# 1618  2021-11-19 04:09:56.813
# 1619  2021-11-19 04:09:56.817
#
# [1620 rows x 6 columns]

# %% [markdown]
# ## Streaming Mode
#
# Read live streaming data and write it to hadoop hdfs in parquet format

# %%
def purchase_sword_event_schema():
    """
    root
    |-- Accept: string (nullable = true)
    |-- Host: string (nullable = true)
    |-- User-Agent: string (nullable = true)
    |-- event_type: string (nullable = true)
    |-- timestamp: string (nullable = true)
    """
    return StructType([
        StructField("Accept", StringType(), True),
        StructField("Host", StringType(), True),
        StructField("User-Agent", StringType(), True),
        StructField("event_type", StringType(), True),
         StructField("sword_size", StringType(), True),
    ])

# %%
@udf('boolean')
def is_sword_purchase(event_as_json):
    """udf for filtering events
    """
    event = json.loads(event_as_json)
    if event['event_type'] == 'purchase_sword':
        return True
    return False

# %%
raw_events = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "kafka:29092") \
    .option("subscribe", "events") \
    .load()

# %%
sword_purchases = raw_events \
    .filter(is_sword_purchase(raw_events.value.cast('string'))) \
    .select(raw_events.value.cast('string').alias('raw_event'),
            raw_events.timestamp.cast('string'),
            from_json(raw_events.value.cast('string'),
                    purchase_sword_event_schema()).alias('json')) \
    .select('raw_event', 'timestamp', 'json.*')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-dd17a2bad60a> in <module>()
#       1 sword_purchases = raw_events     .filter(is_sword_purchase(raw_events.value.cast('string')))     .select(raw_events.value.cast('string').alias('raw_event'),
#       2             raw_events.timestamp.cast('string'),
# ----> 3             from_json(raw_events.value.cast('string'),
#       4                     purchase_sword_event_schema()).alias('json')) \
#       5     .select('raw_event', 'timestamp', 'json.*')
#
# NameError: name 'from_json' is not defined

# %%
sink = sword_purchases \
    .writeStream \
    .format("parquet") \
    .option("checkpointLocation", "/tmp/checkpoints_for_sword_purchases") \
    .option("path", "/tmp/sword_purchases") \
    .trigger(processingTime="10 seconds") \
    .start()

# %% [markdown]
# docker-compose exec cloudera hive

# %% [markdown]
# create external table if not exists default.sword_purchases (Accept string, Host string, `User_Agent` string, event_type string, sword_size string, timestamp string) stored as parquet location '/tmp/sword_purchases'  tblproperties ("parquet.compress"="SNAPPY");

# %% [markdown]
# docker-compose exec presto presto --server presto:8080 --catalog hive --schema default

# %%
sink.stop()

# %% [markdown]
# ## Part W: Simple Analytics - ask 1-2 business questions

# %% [markdown]
# ## Part X: Linux Commands - Tear Down
#
# #### check hadoop hdfs writes
# docker-compose exec cloudera hadoop fs -ls /tmp/
#
# docker-compose exec cloudera hadoop fs -ls /tmp/purchases/
#
# #### tear down cluster
# docker-compose down
#
# docker-compose ps
